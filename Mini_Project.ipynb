# %% [markdown]
# <a href="https://colab.research.google.com/github/Manukarri/Mini-Project--Image-Classification/blob/master/Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
cd /content/drive/My Drive/Smartknower- Internship (Aug-Sep)/Machine Learning
# Out:
# /content/drive/My Drive/Smartknower- Internship (Aug-Sep)/Machine Learning

# %%
# !mkdir images
# Out:
# mkdir: cannot create directory ‘images’: File exists

# %%
cd images
# Out:
# /content/drive/My Drive/Smartknower- Internship (Aug-Sep)/Machine Learning/images

# %%
from bing_image_downloader import downloader
downloader.download("aeroplane", limit= 25, output_dir= 'images')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 25 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/f/fb/Egyptair.a330-200.su-gce.arp.jpg/1200px-Egyptair.a330-200.su-gce.arp.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://1.bp.blogspot.com/-BXKO1VyjlWk/UA5yfCdFsII/AAAAAAAAH4E/K5M0ePZgOV0/s1600/Airplane_aeroplane_aircraft_jet_wallpapers+(30).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://s-i.huffpost.com/gen/1106361/images/o-AIRPLANES-MOBILE-facebook.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.ytimg.com/vi/Elz4-Wx-Yfg/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.ytimg.com/vi/RZowe2Q2oD4/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://4.bp.blogspot.com/-j_Hmejw3rqE/Ts9evAwDWGI/AAAAAAAAAZA/Sz5AlK7ZHWA/s1600/aeroplane-wallpaper-2.jpg
# [%] File Downloaded !
#
# ...

# %%
path= '/content/drive/My Drive/Smartknower- Internship (Aug-Sep)/Machine Learning/images/images/aeroplane/Image_1.jpg'
import cv2 
import matplotlib.pyplot as plt
i= cv2.imread(path)
i= cv2.cvtColor(i, cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
downloader.download("helicopter", limit= 25, output_dir= 'images')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 25 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/7/78/LAPD_Bell_206_Jetranger.jpg/1200px-LAPD_Bell_206_Jetranger.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/UH-72_Volk_field.jpg/1200px-UH-72_Volk_field.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.ytimg.com/vi/-XHnupCDM2A/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Mh60S_Training_Flight_1.jpeg/1200px-Mh60S_Training_Flight_1.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://4.bp.blogspot.com/-We1gpGuGpQY/URomW9cN4DI/AAAAAAAATCE/Y9FJ-IANhZw/w1200-h630-p-k-no-nu/HH+65+Dolphin+US+Coast+Guard+Helicopter+Wallpapers+01.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.ytimg.com/vi/rEy-HxMah14/maxresdefault.jpg
# ...

# %%
path= '/content/drive/My Drive/Smartknower- Internship (Aug-Sep)/Machine Learning/images/images/helicopter/Image_1.jpg'
import cv2 
import matplotlib.pyplot as plt
i= cv2.imread(path)
i= cv2.cvtColor(i, cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
import os
from skimage.io import imread
from skimage.transform import resize

# %%
target= []
flat_data= []
images= []

path= '/content/drive/My Drive/Smartknower- Internship (Aug-Sep)/Machine Learning/images/images'
for dirpath, dirnames, filenames in os.walk(path):
  for filename in filenames:
    category= dirpath.split('/')[-1]
    target.append(category)
target
# Out:
# ['aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'aeroplane',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter',
#  'helicopter']

# %%
target= []
flat_data= []
images= []
import numpy as np
path= '/content/drive/My Drive/Smartknower- Internship (Aug-Sep)/Machine Learning/images/images/'
for dirpath, dirnames, filenames in os.walk(path):
  for filename in filenames:
    category= dirpath.split('/')[-1]
    target.append(category)
    img= imread(f'{path}{category}/{filename}')
    img_resized= resize(img,(100,100,3))
    flat_data.append(img_resized.flatten())
    images.append(img_resized)
flat_data= np.array(flat_data)
target= np.array(target)
images= np.array(images)

print(flat_data.shape)
print(target.shape)
print(images.shape)
# Out:
# (53, 30000)
# (53,)
# (53, 100, 100, 3)

# %%
import pandas as pd
df= pd.DataFrame(flat_data)
df['Target']= target

# %%
df.head()
# Out:
#           0         1         2  ...     29998     29999     Target
# 0  0.201961  0.443137  0.922876  ...  0.431373  0.918954  aeroplane
# 1  0.240523  0.456863  0.924837  ...  0.472549  0.912418  aeroplane
# 2  0.606971  0.643137  0.713725  ...  0.631373  0.672765  aeroplane
# 3  0.000000  0.435294  0.721569  ...  0.756863  0.890196  aeroplane
# 4  0.000000  0.000000  0.384314  ...  0.221804  0.232000  aeroplane
#
# [5 rows x 30001 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Columns: 30001 entries, 0 to Target
# dtypes: float64(30000), object(1)
# memory usage: 12.1+ MB

# %%
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
i= imread('https://www.fleetmon.com/media/cache/newsroom_article_images/yuan/15723faccc8439096d22ecc9f316dedd.jpg')

plt.imshow(i)
model.predict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4a2ca9823cc7> in <module>()
#       5
#       6 plt.imshow(i)
# ----> 7 model.predict()
#
# NameError: name 'model' is not defined

# %%
x= flat_data
y= target

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y, random_state=0)

# %%
from sklearn.svm import SVC

# %%
model= SVC()
model.fit(x_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred= model.predict(x_test)
y_pred
# Out:
# array(['helicopter', 'helicopter', 'helicopter', 'aeroplane', 'aeroplane',
#        'aeroplane', 'aeroplane', 'helicopter', 'aeroplane', 'aeroplane',
#        'aeroplane', 'helicopter', 'aeroplane', 'helicopter'], dtype='<U10')

# %%
y_test
# Out:
# array(['helicopter', 'helicopter', 'helicopter', 'helicopter',
#        'aeroplane', 'aeroplane', 'helicopter', 'helicopter', 'helicopter',
#        'aeroplane', 'aeroplane', 'aeroplane', 'helicopter', 'helicopter'],
#       dtype='<U10')

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.6428571428571429

# %%
confusion_matrix(y_pred, y_test)
# Out:
# array([[4, 4],
#        [1, 5]])
